# %%
import pandas as pd

# %%
dataset1= pd.read_csv("heart4.csv")

# %%
dataset1.shape
# Out:
# (270, 14)

# %%
dataset1.head()
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
# ...

# %%
dataset2= pd.read_csv("merged_dataset.csv")

# %%
dataset2.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    0        140          289          0    172               0
# 1   49    1        160          180          0    156               0
# 2   37    0        130          283          0     98               0
# 3   48    1        138          214          0    108               1
# 4   54    0        150          195          0    122               0
#
#    Oldpeak  ST_Slope  HeartDisease
# 0      0.0       0.0             0
# 1      1.0       1.0             1
# 2      0.0       0.0             0
# 3      1.5       1.0             1
# 4      0.0       0.0             0

# %%
display(dataset1.head())
dataset1.drop(columns=["chest pain type","resting electrocardiographic results","major vessels","thal","ST segment"],inplace=True)
display(dataset1.head())
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
# ...

# %%
dataset1['heart disease'] = dataset1['heart disease'].replace({2: 0})
dataset1.head()
# Out:
#    age  sex   resting blood pressure  serum cholestoral  fasting blood sugar  \
# 0   70     1                     130                322                    0
# 1   67     0                     115                564                    0
# 2   57     1                     124                261                    0
# 3   64     1                     128                263                    0
# 4   74     0                     120                269                    0
#
#    max heart rate  exercise induced angina  oldpeak  heart disease
# 0             109                        0      2.4              0
# 1             160                        0      1.6              1
# 2             141                        0      0.3              0
# 3             105                        1      0.2              1
# 4             121                        1      0.2              1

# %%
dataset2.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    0        140          289          0    172               0
# 1   49    1        160          180          0    156               0
# 2   37    0        130          283          0     98               0
# 3   48    1        138          214          0    108               1
# 4   54    0        150          195          0    122               0
#
#    Oldpeak  ST_Slope  HeartDisease
# 0      0.0       0.0             0
# 1      1.0       1.0             1
# 2      0.0       0.0             0
# 3      1.5       1.0             1
# 4      0.0       0.0             0

# %%
display(dataset1.shape,dataset2.shape)
# Out:
# (270, 9)
# (1943, 10)

# %%
dataset1.head()
# The fillna method ensures that any value not present in the replacement_map remains unchanged
# Out:
#    age  sex   resting blood pressure  serum cholestoral  fasting blood sugar  \
# 0   70     1                     130                322                    0
# 1   67     0                     115                564                    0
# 2   57     1                     124                261                    0
# 3   64     1                     128                263                    0
# 4   74     0                     120                269                    0
#
#    max heart rate  exercise induced angina  oldpeak  heart disease
# 0             109                        0      2.4              0
# 1             160                        0      1.6              1
# 2             141                        0      0.3              0
# 3             105                        1      0.2              1
# 4             121                        1      0.2              1

# %%
dataset1.rename(columns={'age':'Age','sex ':'Sex','resting blood pressure':'RestingBP','serum cholestoral':'Cholesterol','fasting blood sugar':'FastingBS','max heart rate':'MaxHR','exercise induced angina':'ExerciseAngina','oldpeak':'Oldpeak','ST segment':'ST_Slope','heart disease':'HeartDisease'}, inplace= True)

# %%
display(dataset1.head(5))
dataset2.head(10)
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   70    1        130          322          0    109               0
# 1   67    0        115          564          0    160               0
# 2   57    1        124          261          0    141               0
# 3   64    1        128          263          0    105               1
# 4   74    0        120          269          0    121               1
#
#    Oldpeak  HeartDisease
# 0      2.4             0
# 1      1.6             1
# 2      0.3             0
# 3      0.2             1
# 4      0.2             1
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  ExerciseAngina  \
# 0   40    0        140          289          0    172               0
# 1   49    1        160          180          0    156               0
# 2   37    0        130          283          0     98               0
# 3   48    1        138          214          0    108               1
# ...

# %%
dataset1.to_csv('testingdata2.csv', index=False)
